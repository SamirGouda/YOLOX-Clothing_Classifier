# %%
! python -m yolox.tools.eval -n  yolox-s -c YOLOX/models/yolox_s.pth -b 16 -d 1 --conf 0.001 --fp16
# Out:
# 2022-12-19 11:01:14 | INFO     | __main__:139 - Args: Namespace(experiment_name='yolox_s', name='yolox-s', dist_backend='nccl', dist_url=None, batch_size=16, devices=1, num_machines=1, machine_rank=0, exp_file=None, ckpt='YOLOX/models/yolox_s.pth', conf=0.001, nms=None, tsize=None, seed=None, fp16=True, fuse=False, trt=False, legacy=False, test=False, speed=False, opts=[])
# [W NNPACK.cpp:79] Could not initialize NNPACK! Reason: Unsupported hardware.
# 2022-12-19 11:01:15 | INFO     | __main__:149 - Model Summary: Params: 8.97M, Gflops: 26.93
# 2022-12-19 11:01:15 | INFO     | __main__:150 - Model Structure:
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
# ...
